# %% [markdown]
# <img src="http://ewoutreinders.com/wp-content/uploads/2015/06/prg-banner-201309.jpg" height="602" width="602"></img>
#
#  <center>
#  <H1>
# IMPERATIVE PROGRAMMING
# </H1>
# </center>
# <H2>
# <i>Instructor</i>
# </H2>
# <H4>
# Roger Guzmán
# <br>
# Programa de Ingeniería de Sistemas y Computación
# <br>
# Universidad Católica de Colombia
# </H4>
# <center>
#  <H2>
# Course Description
# </H2>
# </center>
#  <H3>
# Objective
# </H3>
# <P>
# The goal of this course is to study the elements that support to student realize  the activities used for learning imperative programming. The student must know discrete mathematics, computer programming, basics mathematics, linear algebra and arithmetic.
# </P>
# <H3>
# Methodology
# </H3>
# <ul>
# <li>Professor's master classes.</li>
# <li>Question and dudes solving by students and teacher.</li>
# <li>Assignment will be presented in pdf format make it with Latex using <a href="https://www.overleaf.com/">overleaf</a> [<a href="https://medium.com/thoughts-philosophy-writing/how-to-use-overleaf-to-write-your-papers-part-i-basic-minimalist-setup-6599268c095f"> How to use Overleaf </a>].</li>
# <li><b>Programming languages</b>
# <ul>
# <li>C++ Language [<a href="http://zinjai.sourceforge.net/index.php?page=descargas.php">Zinjai</a>]</li>
# </ul>
# </li>
# <li>Individual-Exam, Two-person exam, Home Exam.</li>
# <li>Final Project!</li>
#
# </ul>
# <H3>
# Evaluation and grading policy
# </H3>
# <br>
#
# <table>
#     <tr>
#         <td bgcolor="#000000"><center><font color="#FFFFFF">Grades</font></center></td>
#         <td><b><center>First Term /30</b></td>
#         <td><b><center>Second Term /30</b></td>
#         <td><b><center>Third Term /40</b></td>
#     </tr>
#     <tr>
#         <td><center>Assignments</center></td>
#         <td><center>20%</center></td>
#         <td><center>20%</center></td>
#         <td><center>-/-</center></td>
#     </tr>
#     <tr>
#         <td><center>Quices</center></td>
#         <td><center>20%</center></td>
#         <td><center>20%</center></td>
#         <td><center>10%</center></td>
#     </tr>
#     <tr>
#         <td><center>Exam</center></td>
#         <td><center>50%</center></td>
#         <td><center>50%</center></td>
#         <td><center>50%</center></td>
#     </tr>
#
#     <tr>
#         <td><center>Final Project</center></td>
#         <td><center>10%</center></td>
#         <td><center>10%</center></td>
#         <td><center>40%</center></td>
#     </tr>
#     <tr>
#         <td><center><b>Total</b></center></td>
#         <td><center>100%</center></td>
#         <td><center>100%</center></td>
#         <td><center>100%</center></td>
#     </tr>
# </table>
# </center>
# <h3>
# Course Schedule
# </h3>
# <table class="table table-condensed">
#     <tbody>
#     <tr>
#         <th>Week</th>
#         <th>Topic</th>
#         <th>Material</th>
#         <th>Assignments</th>
#     </tr>
#     <h6>
#     <tr>
#
#         <th>1 </th>
#         <th><font size="1">
#         <ul>
#         <li>Course presentation</li>
#         <li>System definition</li>
#         <li></li>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#
#     </tr>
#     <tr>
#         <th>2</th>
#         <th><font size="1">
#         <ul>
#         <li> Introduction to C++ Language</li>
#         <ul>
#         <li>Variable and Type Data</li>
#         <li>Review C++ Language for computer programming</li>
#         <li>Logic Operators</li>
#         <li>Aritmethic Operators</li>
#         </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>3</th>
#         <th><font size="1">
#         <ul>
#         <li> Introduction to C++ Language</li>
#             <ul>
#             <li>Review Decision Sentence</li>
#             <ul>
#                 <li>If-Then</li>
#                 <li>Switch - Case</li>
#             </ul>
#             <li>Review Nested Decision Sentence</li>
#             <li>Review Repetitive Sentence</li>
#             <ul>
#                 <li>While</li>
#                 <li>do-while</li>
#                 <li>for</li>
#             </ul>
#             <li>Review Nested Repetitive Sentence</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>4</th>
#         <th><font size="1">
#             <ul>
#             <li>Structured Programming - Static memory</li>
#                 <ul>
#                 <li>Array Definition</li>
#                 <li>Coding Array-Unidimensional</li>
#                 <li>Sorting Algorithms</li>
#                 </ul>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>5</th>
#         <th><font size="1">
#             <ul>
#             <li>Structured Programming - Static memory</li>
#                 <ul>
#                 <li>Array Definition</li>
#                 <li>Matrix Definition</li>
#                 <li>Coding Array-Multidimensional or Matrices</li>
#                 <li>Exercises and Examples</li>
#
#                 </ul>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#
#     <tr>
#         <th>6</th>
#         <th><font size="1">
#             <ul>
#             <li>Structured Programming</li>
#                 <ul>
#                 <li>Definition functions</li>
#                 <li>Coding functions in C++</li>
#                 <li>Invoke functions in C++ and return Parameters</li>
#                 </ul>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>7</th>
#         <th><font size="1">
#             <ul>
#             <li>Structured Programming</li>
#                 <ul>
#                 <li>Value Parameters for functions</li>
#                 <li>DataType Value Parameters for functions</li>
#                 <li>Referenced Parameters for functions</li>
#                 <li>DataType Referenced Parameters for functions</li>
#                 </ul>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#
#
#     <tr>
#         <th>8</th>
#         <th><font size="1">
#         <ul>
#         <li>Recursion Definition</li>
#             <ul>
#                 <li>Mathematical Definition</li>
#                 <li>Computational Representation for Recursive Function</li>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>9</th>
#         <th><font size="1">
#         <ul>
#         <li>Recursion Definition</li>
#             <ul>
#                 <li>Binary Search using Recursive Representation</li>
#                 <li>MergeSort Sort Algorithm Implementation</li>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>10</th>
#         <th>
#         <font size="1">
#         <ul>
#         <li>Dynamic Memory</li>
#             <ul>
#             <li>Memory Segments and Pointers</li>
#             <li>Hexadecimal representation and dynamic Asignation</li>
#             </ul>
#         </ul>
#         </font>
#         </th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#          <th>11</th>
#         <th>
#         <font size="1">
#         <ul>
#         <li>TAD Structures</li>
#             <ul>
#             <li>Linked List, Node definition</li>
#             <li>Circular Linked List</li>
#                 <ul>
#                     <li>Create Head-Tail-intermediate Node</li>
#                     <li>Erase Head-Tail-intermediate Node</li>
#                     <li>Searching and Updating information for Node</li>
#                 </ul>
#             </ul>
#         </ul>
#         </font>
#         </th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>12</th>
#         <th><font size="1">
#         <ul>
#         <li>TAD Structures</li>
#             <ul>
#             <li>Double Linked List</li>
#             <li>Circular Double Linked List</li>
#             <ul>
#                     <li>Create Head-Tail-intermediate Node</li>
#                     <li>Erase Head-Tail-intermediate Node</li>
#                     <li>Searching and Updating information for Node</li>
#                 </ul>
#             <li>Management File in C++</li>
#             <ul>
#                 <li>Creation</li>
#                 <li>Write and Read</li>
#                 <li>Delete</li>
#             </ul>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#
#     <tr>
#         <th>13</th>
#         <th><font size="1">
#         <ul>
#         <li>TAD Structures</li>
#             <ul>
#             <li>Multi-Linked List</li>
#             <ul>
#                     <li>Create Head-Tail-intermediate Multi-Node</li>
#                     <li>Erase Head-Tail-intermediate Multi-Node</li>
#                     <li>Searching and Updating information for Multi-Node</li>
#                 </ul>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     </h6>
#     </tbody>
#
#
# </table>
#
# <H3>Course resources</H3>
# <h4>Books</h4>
# <ul>
# <li>Becerra, C. Algoritmos, Conceptos básicos. 1996, Bogotá.</li>
# <li>
# Cairó, O. Metodología de la programación, 2003. Ed, 2. Mexico D.F. AlfaOmega.
# </li>
# <li>Castro Ch, I. El arte de razonar. 2003.Bogotá. Pontificia Universidad Javeriana.</li>
# <li>Gusti, A. Algoritmos, Datos y Programas. 2001. Mexico D.F.Prentice Hall. </li>
# <li>Joyanes, L Fundamentos de programación. Edición 3.2003.Madrid. Prentice Hall. [<a href="https://www.slideshare.net/reimerxd/fundamentos-de-la-programacion-luis-joyanes-3era-edicion">Link</a>]</li>
# </ul>
# <h4>Courses</h4>
# <ul>
# <li>Grimson, E. Guttah, J. Introduction to Computer Science and Programming. 2008. [<a href="https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-00-introduction-to-computer-science-and-programming-fall-2008/index.htm">link</a>]</li>
# </ul>
