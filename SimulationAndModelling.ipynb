# %% [markdown]
# <img src="https://www.uni-bonn.de/research/research-profile/key-profile-areas/images/KPAMathematicsSlider1160x420.jpg" height="502" width="502"></img>
#
#  <center>
#  <H1>
# Modelling and  Simulation
# </H1>
# </center>
# <H2>
# <i>Instructor</i>
# </H2>
# <H4>
# Roger Guzmán
# <br>
# Programa de Ingeniería de Sistemas y Computación
# <br>
# Universidad Católica de Colombia
# <br>
# Msc. Universidad Nacional de Colombia. Computer Science
# </H4>
# <center>
#  <H2>
# Course Description
# </H2>
# </center>
#  <H3>
# Objective
# </H3>
# <P>
# The goal of this course is to study the elements that support to student realize  the activities used for mathematical and probabilistic modelling, simulating systems applied to real life. The student must <b>know basics mathematics, data structures, computer programming, differential equations, computer science, statistics, linear algebra, probability, discrete mathematics, multi-variable calculus,pphysics mechanics and electromagnetic, operations research, numerical methods, operations research, analysis and design algorithms, stochastic processes.</b>.
# </P>
# <H3>
# Methodology
# </H3>
# <ul>
# <li>Professor's master classes.</li>
# <li>Question and dudes solving by students and teacher.</li>
# <li>Assignment will be presented in pdf format make it with Latex using <a href="https://www.overleaf.com/">overleaf</a> [<a href="https://medium.com/thoughts-philosophy-writing/how-to-use-overleaf-to-write-your-papers-part-i-basic-minimalist-setup-6599268c095f"> How to use Overleaf </a>].</li>
# <li><b>Programming languages</b>
# <ul>
# <li>Python [<a href="http://jupyter.org/">Jupyter Notebook</a>]</li>
# <li>R-programming [<a href="https://www.rstudio.com/">R Studio</a>]</li>
# <li>Open-CV [<a href="https://opencv.org/">OpenCV</a>]</li>
# <li>Scikit-Learn [<a href="https://scikit-learn.org/stable/">Machine Learning Scikit Learn</a>]</li>
# <li>DataCamp[<a href="https://www.datacamp.com/?utm_source=adwords_ppc&utm_campaignid=1242944157&utm_adgroupid=58673827368&utm_device=c&utm_keyword=datacamp&utm_matchtype=e&utm_network=g&utm_adpostion=1t1&utm_creative=340731356764&utm_targetid=aud-299261629574:kwd-297372810188&utm_loc_interest_ms=&utm_loc_physical_ms=1003659&gclid=EAIaIQobChMIpcqRjv2k5wIVHoVaBR1yUwCIEAAYASAAEgKNfvD_BwE">DataCamp App</a>]</li>
# </ul>
# </li>
# <li>Individual-Exam, Two-person exam, Home Exam.</li>
# <li>Final Project!</li>
#
# </ul>
# <H3>
# Evaluation and grading policy
# </H3>
# <br>
#
# <table>
#     <tr>
#         <td bgcolor="#000000"><center><font color="#FFFFFF">Grades</font></center></td>
#         <td><b><center>First Term /30</b></td>
#         <td><b><center>Second Term /30</b></td>
#         <td><b><center>Third Term /40</b></td>
#     </tr>
#     <tr>
#         <td><center>Assignments</center></td>
#         <td><center>6</center></td>
#         <td><center>6</center></td>
#         <td><center>-/-</center></td>
#     </tr>
#     <tr>
#         <td><center>Quices</center></td>
#         <td><center>6</center></td>
#         <td><center>6</center></td>
#         <td><center>-/-</center></td>
#     </tr>
#     <tr>
#         <td><center>Exam</center></td>
#         <td><center>15</center></td>
#         <td><center>15</center></td>
#         <td><center>20</center></td>
#     </tr>
#     <tr>
#         <td><center>Paper</center></td>
#         <td><center>1.5</center></td>
#         <td><center>1.5</center></td>
#         <td><center>10</center></td>
#     </tr>
#     <tr>
#         <td><center>Final Project</center></td>
#         <td><center>1.5</center></td>
#         <td><center>1.5</center></td>
#         <td><center>10</center></td>
#     </tr>
#     <tr>
#         <td><center><b>Total</b></center></td>
#         <td><center>30</center></td>
#         <td><center>30</center></td>
#         <td><center>40</center></td>
#     </tr>
# </table>
# </center>
# <h3>
# Course Schedule
# </h3>
# <table>
#    <tr>
#        <td ><center>Week</center></td>
#        <td><center>Topic</center></td>
#        <td><center>Material</center></td>
#        <td><center>Assigment</center></td>
#     </tr>
#    <tr>
#        <td>1</td>
#        <td>
#            <center>
#          <ul>
#         <li><b>Mathematics as a Natural Modeling Language</b>
#         <li>Modeling a Black Box System
#         <li>SQM Space Classification
#         <li>Linear Programming
#         <li>Constraint and Optimization Problem
#         <li>Graphical Method solution
# </ul>
#            </center>
#        </td>
#          <td></td>
#         <td></td>
#     </tr>
#     <tr>
#        <td>2</td>
#         <td>
#            <center>
#            <ul>
# 	<li><b>Linear Programming</b>
#         <li>Simplex Algorithm
#         <li>Computational Complexity
#         <li>Convex Problem and Polyhedra
#         <li>KKT and Support Vector Machine
# </ul>
#            </center>
#        </td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#        <td>3</td>
#         <td>
#            <center>
#            <ul>
# 	<li><b>Phenomenological Models</b>
#         <li>Elementary Statistics
#         <li>Descriptive Statistics
#         <li>Random Processes and Probability
#         <li>Densities and Distributions
#         <li>Inferential Statistic
#         <li>Hypothesis Test
# </ul>
#            </center>
#        </td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#        <td>4</td>
#         <td>
#            <center>
#            <ul>
#             <li><b>Mechanistic Models</b>
#                 <li>Mechanical Physics
#                 <li>Uniform line motion
#                 <li>Uniform Accelerated Motion
#                 <li>Ordinary Differential Equations
#                 <li>Stella Simulation
#                 <li>Threads and Computer Programming
#             </ul>
#            </center>
#        </td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#        <td>5-6-7</td>
#         <td>
#            <center>
#            <ul>
#             <li><b>ODE's Numerical Methods</b>
#                 <li>Finding Roots
#                 <li>Newton-Raphson Algorithm
#                 <li>Derivate and Integration Functions
#                 <li>Runge Kutta (4th order)
#                 <li>Euler Maruyama
#                 <li><b>*Exam*</b></li>
#             </ul>
#            </center>
#        </td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#            <td>9-10</td>
#             <td>
#                <center>
#                <ul>
#         <li><b>Partial Differential Equations</b>
#             <li>First-order PDEs , Second-order PDEs
#             <li>Elliptic, Parabolic, and Hyperbolic Equations
#             <li>Random Processes and Probability
#             <li>Densities and Distributions
#             <li>Inferential Statistic
#             <li>Hypothesis Test
#     </ul>
#            </center>
#        </td>
#         <td></td>
#         <td></td>
#     </tr>
#      <tr>
#        <td>11-12-13</td>
#         <td>
#            <center>
#            <ul>
# 	<li><b>The Finite-Element Method</b>
#         <li>Weak Formulation of PDEs
#         <li>PDE Programming
#         <li>Diffusion and Convection
#         <li>Computational Fluid Dynamics
#         <li>Navier–Stokes Equations
#         <li><b>*Exam*</b>
# </ul>
#            </center>
#        </td>
#         <td></td>
#         <td></td>
#     </tr>
#      <tr>
#        <td>14-15-16</td>
#         <td>
#            <center>
#            <ul>
# 	<li><b>Petri Nets</b>
#         <li>Petri Net Graphs
#         <li>Analysis of PetriNets
#         <li>Marked Graphs
#     </ul>
#            </center>
#        </td>
#         <td></td>
#         <td></td>
#     </tr>
#
# </table>
#
# <H3>Course resources</H3>
# <h4>Books</h4>
# <ul>
# <li>Information Retrieval [<a href="https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf">Link</a>]</li>
# <li>
# Probabilistic Programming and Bayesian Methods for Hackers
# [<a href="">Link</a>]
# </li>
# <li>Petri Nets Theory and The Modelling Systems.Peterson.</li>
# <li>Hue, Tue Huynh. Stochastic simulation and Applications in Finance with Matlab Programs.2008.Wiley. </li>
# <li>Field Richard. Stochastic Models: Theory and Simulation.2008.Sandia Laboratories.</li>
# <li> Knill, Oliver.Probability Theory and Stochastic Processes with Applications.2009.Overseas Press.</li>
# <li>Winston, Wayne. Investigación de Operaciones Aplicaciones y Algoritmos. 2004. Thomson Ed.</li>
# <li> Hillier, Liebermann. Introducción a la Investigación de Operaciones. 2010.</li>
# <li>Varela Carlos. Introducción a la Investigación de Operaciones. 1994.</li>
# </ul>
# <h4>Courses</h4>
# <ul>
# <li>MIT-Course- Discrete Stochastic Process [<a href="https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-262-discrete-stochastic-processes-spring-2011/">link</a>]</li>
# <li>Girke, Thomas. R- Programming [<a href= "http://manuals.bioinformatics.ucr.edu/home/programming-in-r">link</a>] </li>
#
# <li>Coursera, R- Programming [<a href= "https://www.coursera.org/course/rprog">link</a>]  </li>
# <li>Coursera, Machine Learning [<a href= "https://www.coursera.org/learn/machine-learning">link</a>]  </li>
#
# </ul>
