# %% [markdown]
# <img src="https://www.edx.org/sites/default/files/course/image/promoted/009x_banner_378x225.jpg" height="502" width="502"></img>
#
#  <center>
#  <H1>
# ALGORITHMS AND STOCHASTIC ANALYSIS
# </H1>
# </center>
# <H2>
# <i>Instructor</i>
# </H2>
# <H4>
# Roger Guzmán
# <br>
# Programa de Ingeniería de Sistemas y Computación
# <br>
# Universidad Católica de Colombia
# <br>
# Msc. Universidad Nacional de Colombia. Computer Science
# </H4>
# <center>
#  <H2>
# Course Description
# </H2>
# </center>
#  <H3>
# Objective
# </H3>
# <P>
# The goal of this course is to study the elements that support to student realize  the activities used for mathematical and probabilistic modelling, simulating systems applied to real life. The student must <b>know basics mathematics, data structures, computer programming, differential equations, computer science, statistics, linear algebra, probability, discrete mathematics, multi-variable calculus, operations research, numerical methods, operations research, analysis and design algorithms</b>.
# </P>
# <H3>
# Methodology
# </H3>
# <ul>
# <li>Professor's master classes.</li>
# <li>Question and dudes solving by students and teacher.</li>
# <li>Assignment will be presented in pdf format make it with Latex using <a href="https://www.overleaf.com/">overleaf</a> [<a href="https://medium.com/thoughts-philosophy-writing/how-to-use-overleaf-to-write-your-papers-part-i-basic-minimalist-setup-6599268c095f"> How to use Overleaf </a>].</li>
# <li><b>Programming languages</b>
# <ul>
# <li>Python [<a href="http://jupyter.org/">Jupyter Notebook</a>]</li>
# <li>R-programming [<a href="https://www.rstudio.com/">R Studio</a>]</li>
# <li>Open-CV [<a href="https://opencv.org/">OpenCV</a>]</li>
# <li>Scikit-Learn [<a href="https://scikit-learn.org/stable/">Machine Learning Scikit Learn</a>]</li>
# <li>IBM WATSON [<a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/ml-mnist-tutorials.html/">IBM watson</a>]</li>
# <li>Microsoft Azure [<a href="https://docs.microsoft.com/en-in/azure/cognitive-services/computer-vision/home?fbclid=IwAR3GPDIq-v7beLho5q3b5apG-hxRI1mGAPZZQzrEVs7g-iPG7KSDnuDyB7w/">Azure</a>]</li>
# <li> AWS Recognition[<a href="https://aws.amazon.com/es/rekognition/">AWS - Amazon</a>]</li>
# </ul>
# </li>
# <li>Individual-Exam, Two-person exam, Home Exam.</li>
# <li>Final Project!</li>
#
# </ul>
# <H3>
# Evaluation and grading policy
# </H3>
# <br>
#
# <table>
#     <tr>
#         <td bgcolor="#000000"><center><font color="#FFFFFF">Grades</font></center></td>
#         <td><b><center>First Term /30</b></td>
#         <td><b><center>Second Term /30</b></td>
#         <td><b><center>Third Term /40</b></td>
#     </tr>
#     <tr>
#         <td><center>Assignments</center></td>
#         <td><center>6</center></td>
#         <td><center>6</center></td>
#         <td><center>-/-</center></td>
#     </tr>
#     <tr>
#         <td><center>Quices</center></td>
#         <td><center>5</center></td>
#         <td><center>5</center></td>
#         <td><center>-/-</center></td>
#     </tr>
#     <tr>
#         <td><center>Exam</center></td>
#         <td><center>15</center></td>
#         <td><center>15</center></td>
#         <td><center>20</center></td>
#     </tr>
#     <tr>
#         <td><center>Paper</center></td>
#         <td><center>1.5</center></td>
#         <td><center>1.5</center></td>
#         <td><center>10</center></td>
#     </tr>
#     <tr>
#         <td><center>Final Project</center></td>
#         <td><center>1.5</center></td>
#         <td><center>1.5</center></td>
#         <td><center>10</center></td>
#     </tr>
#     <tr>
#         <td><center><b>Total</b></center></td>
#         <td><center>30</center></td>
#         <td><center>30</center></td>
#         <td><center>40</center></td>
#     </tr>
# </table>
# </center>
# <h3>
# Course Schedule
# </h3>
# <table class="table table-condensed">
#     <tbody>
#     <tr>
#         <th>Week</th>
#         <th>Topic</th>
#         <th>Material</th>
#         <th>Assignments</th>
#     </tr>
#     <h6>
#     <tr>
#
#         <th>1 </th>
#         <th><font size="1">
#         <ul>
#         <li>Course presentation</li>
#         <li>An brief introduction to simulation and stochastic processes.</li>
#         <li>A review of Statistics and Probability Theory</li>
#         <li>Axioms of Probability</li>
#         </ul>
#         </font></th>
#         <th>
#         <ul>
#         <li><a href="https://drive.google.com/file/d/0B6xE724XtKXXc0JJX19BU3RJM0k/view">Introduction to simulation and stochastic processes</a></li>
#         <li><a href="https://www.cs.princeton.edu/courses/archive/spring07/cos424/scribe_notes/0208.pdf">Review Probability Stanford</a></li>
#         <li><a href="https://drive.google.com/file/d/0B6xE724XtKXXWi1VUkZQYXFMZzQ/view">Theory of probability</a></li>
#         </ul>
#         </th>
#         <th></th>
#
#     </tr>
#     <tr>
#         <th>2</th>
#         <th><font size="1">
#         <ul>
#         <li> A review of Statistics and Probability Theory</li>
#         <ul>
#         <li>Theory of Probability</li>
#         <li>Expected Value</li>
#         <li>Discrete Probability Distrubution</li>
#         <li>Continous Probability Distrubution</li>
#         </ul>
#         </ul>
#         </font></th>
#         <th>
#         <ul>
#         <li>
#         <a href="https://drive.google.com/file/d/0B6xE724XtKXXQVM4cUxRNWtrRkk/view">Probability Theory</a>
#         </li>
#         <li>
#         <a href="https://drive.google.com/file/d/0B6xE724XtKXXWnpuMlZmbkVpZk0/view">Expected Value</a>
#         </li>
#         </ul>
#         </th>
#         <th>
#
#         </th>
#     </tr>
#     <tr>
#         <th>3</th>
#         <th><font size="1">
#         <ul>
#             <li> Probability Theory</li>
#             <ul>
#             <li>Statistical Moments of Probability Distribution</li>
#             <li>Central Moment of Probability Distribution</li>
#             <li>Bayes' Rule</li>
#             <li>Total Probability Theory</li>
#             <li>Marginal Probability</li>
#             </ul>
#         </ul>
#         </font>
#         </th>
#         <th>
#         <a href="http://www.maths.qmul.ac.uk/~bb/MS_Lectures_5and6.pdf">Statistical Moments Of probability</a>
#         <a href="https://drive.google.com/file/d/0B6xE724XtKXXWnpuMlZmbkVpZk0/view">Statistical Moments Of probability II</a>
#         <!--
#         <ul>
#         <li>
#
#         </li>
#         <li>
#
#         </li>
#         </ul>
#         -->
#
#
#         </th>
#         <th></th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Quiz</th>
#     </tr>
#
#     <tr>
#         <th>4-5</th>
#
#         <th><font size="1">
#             <ul>
#             <li>Bayesian Inference</li>
#                 <ul>
#                 <li>Prior, Posterior, Likelihood  and Normalization</li>
#                 <li>Maximum Likelihood Estimation</li>
#                 <li>Algorithms on Probability Estimation</li>
#                 <li>Gradient Descent</li>
#                 <li>Numerical multidimensional root finding</li>
#                 </ul>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Quiz</th>
#     </tr>
#     <tr>
#         <th colspan="4" style="text-align: center; vertical-align: middle;">Paper Presentation</th>
#
#         <!--
#         <th><font size="1">
#         <ul>
#         <li>Exam 1</li>
#         </ul>
#         </font></th>
#         <th><a href="https://github.com/roheru/mathematical/blob/master/Exams/Stochastic%20Processes%20First%20Exam.pdf">First Exam</a></th>
#         <th></th>
#         -->
#     </tr>
#     <tr>
#         <th>6</th>
#         <th><font size="1">
#         <ul>
#         <li>Randomized Algorithms</li>
#             <ul>
#             <li>Review of Computational Complexity</li>
#                 <ul>
#                 <li>Big-Oh, Omega, Theta, Asymptotic Notation</li>
#                 <li>Recursive Algorithms</li>
#                 <li>Master Theorem</li>
#                 </ul>
#             <li></li>
#             <li>Hiring Problem</li>
#             <li>Min-Cut Algorithm</li>
#             <li>QuickSort Algorithm and Probabilistic Complexity</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Exam 1</th>
#     </tr>
#     <tr>
#         <th>7</th>
#         <th><font size="1">
#         <ul>
#         <li>Stochastic Processes</li>
#             <ul>
#             <li>Birth and Death Processes</li>
#             <li>Markov Chain Definition and Properties</li>
#             <li>Chapman Kolomgorov and Steady State Probability</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>8</th>
#         <th><font size="1">
#         <ul>
#             <li>Stochastic Processes</li>
#                 <ul>
#                     <li>Markov Chain Applications</li>
#                 </ul>
#         </ul>
#         <ul>
#             <li>Information Retrieval</li>
#                 <ul>
#                     <li>Foundations Theory of Information Retrieval</li>
#                 </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Quiz</th>
#     </tr>
#
#     <tr>
#         <th>9-10</th>
#         <th><font size="1">
#         <ul>
#             <li>Stochastic Modelling and information Retrieval</li>
#             <ul>
#                 <li>Inverse document frequency</li>
#                 <li>Document Analysis</li>
#                 <li>WebSurfing and Dangling Pages</li>
#                 <li>Page Rank</li>
#                 <li>Naive Bayes Algorithm</li>
#
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#     <th colspan="4" style="text-align: center; vertical-align: middle;"> Paper Presentation
#     </th>
#     </tr>
#     <tr>
#         <th>11-12</th>
#         <th><font size="1">
#         <ul>
#         <li>Bayesian Theory</li>
#             <ul>
#             <li>Bayesian Networks</li>
#             <li>Graphical Models</li>
#             <li>Conditional Independence</li>
#
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Quiz</th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Exam 2</th>
#     </tr>
#
#     <tr>
#         <th>13-14</th>
#         <th><font size="1">
#         <ul>
#             <li>Graphical Model Applications</li>
#
#             <ul>
#                 <li>Markov Random Fields</li>
#                 <li>Conditional independence properties</li>
#                 <li>Factorization properties</li>
#                 <li>Inference in Graphical Models</li>
#             </ul>
#             <li>Hidden Markov Models</li>
#
#             <ul>
#                 <li>Emission Probabilities</li>
#                 <li>Joint probability distribution</li>
#                 <li>Generative model</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Paper Presentation</th>
#     </tr>
#
#     <tr>
#         <th>15-16</th>
#         <th><font size="1">
#         <ul>
#             <li>Stochastic Modelling</li>
#             <ul>
#             <li>Queue Theory</li>
#             <li>M/M/1</li>
#             <li>M/M/S/K</li>
#             <li>M/M/1/Er</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th colspan="4"  style="text-align: center; vertical-align: middle;">Final Exam</th>
#     </tr>
#
#
#
#     </h6>
#     </tbody>
#
#
# </table>
#
# <H3>Course resources</H3>
# <h4>Books</h4>
# <ul>
# <li>Information Retrieval [<a href="https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf">Link</a>]</li>
# <li>
# Probabilistic Programming and Bayesian Methods for Hackers
# [<a href="">Link</a>]
# </li>
# <li>Gallager, Robert. Stochastic Processes Theory and Applications.</li>
# <li>Hue, Tue Huynh. Stochastic simulation and Applications in Finance with Matlab Programs.2008.Wiley. </li>
# <li>Field Richard. Stochastic Models: Theory and Simulation.2008.Sandia Laboratories.</li>
# <li> Knill, Oliver.Probability Theory and Stochastic Processes with Applications.2009.Overseas Press.</li>
# <li>Winston, Wayne. Investigación de Operaciones Aplicaciones y Algoritmos. 2004. Thomson Ed.</li>
# <li> Hillier, Liebermann. Introducción a la Investigación de Operaciones. 2010.</li>
# <li>Varela Carlos. Introducción a la Investigación de Operaciones. 1994.</li>
# </ul>
# <h4>Courses</h4>
# <ul>
# <li>MIT-Course- Discrete Stochastic Process [<a href="https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-262-discrete-stochastic-processes-spring-2011/">link</a>]</li>
# <li>Girke, Thomas. R- Programming [<a href= "http://manuals.bioinformatics.ucr.edu/home/programming-in-r">link</a>] </li>
#
# <li>Coursera, R- Programming [<a href= "https://www.coursera.org/course/rprog">link</a>]  </li>
# <li>Coursera, Machine Learning [<a href= "https://www.coursera.org/learn/machine-learning">link</a>]  </li>
#
# </ul>
