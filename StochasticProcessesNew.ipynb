# %% [markdown]
# <img src="https://www.intechopen.com/source/html/42874/media/image1.png" height="502" width="502"></img>
#
#  <center>
#  <H1>
# STOCHASTIC PROCESSES AND SIMULATION
# </H1>
# </center>
# <H2>
# <i>Instructor</i>
# </H2>
# <H4>
# Roger Guzmán
# <br>
# Programa de Ingeniería de Sistemas y Computación
# <br>
# Universidad Católica de Colombia
# </H4>
# <center>
#  <H2>
# Course Description
# </H2>
# </center>
#  <H3>
# Objective
# </H3>
# <P>
# The goal of this course is to study the elements that support to student realize  the activities used for mathematical and probabilistic modelling, simulating systems applied to real life. The student must know basics mathematics, data structures, computer programming, differential equations, computer science, statistics, linear algebra, probability, discrete mathematics, multi-variable calculus, operations research, analysis and design algorithms.
# </P>
# <H3>
# Methodology
# </H3>
# <ul>
# <li>Professor's master classes.</li>
# <li>Question and dudes solving by students and teacher.</li>
# <li>Assignment will be presented in pdf format make it with Latex using <a href="https://www.overleaf.com/">overleaf</a> [<a href="https://medium.com/thoughts-philosophy-writing/how-to-use-overleaf-to-write-your-papers-part-i-basic-minimalist-setup-6599268c095f"> How to use Overleaf </a>].</li>
# <li><b>Programming languages</b>
# <ul>
# <li>Python [<a href="http://jupyter.org/">Jupyter Notebook</a>]</li>
# <li>R-programming [<a href="https://www.rstudio.com/">R Studio</a>]</li>
# </ul>
# </li>
# <li>Individual-Exam, Two-person exam, Home Exam.</li>
# <li>Final Project!</li>
#
# </ul>
# <H3>
# Evaluation and grading policy
# </H3>
# <br>
#
# <table>
#     <tr>
#         <td bgcolor="#000000"><center><font color="#FFFFFF">Grades</font></center></td>
#         <td><b><center>First Term /30</b></td>
#         <td><b><center>Second Term /30</b></td>
#         <td><b><center>Third Term /40</b></td>
#     </tr>
#     <tr>
#         <td><center>Assignments</center></td>
#         <td><center>20%</center></td>
#         <td><center>20%</center></td>
#         <td><center>-/-</center></td>
#     </tr>
#     <tr>
#         <td><center>Quices</center></td>
#         <td><center>14%</center></td>
#         <td><center>14%</center></td>
#         <td><center>-/-</center></td>
#     </tr>
#     <tr>
#         <td><center>Exam</center></td>
#         <td><center>50%</center></td>
#         <td><center>50%</center></td>
#         <td><center>50%</center></td>
#     </tr>
#     <tr>
#         <td><center>Paper</center></td>
#         <td><center>10%</center></td>
#         <td><center>10%</center></td>
#         <td><center>25%</center></td>
#     </tr>
#     <tr>
#         <td><center>Final Project</center></td>
#         <td><center>6%</center></td>
#         <td><center>6%</center></td>
#         <td><center>25%</center></td>
#     </tr>
#     <tr>
#         <td><center><b>Total</b></center></td>
#         <td><center>100%</center></td>
#         <td><center>100%</center></td>
#         <td><center>100%</center></td>
#     </tr>
# </table>
# </center>
# <h3>
# Course Schedule
# </h3>
# <table class="table table-condensed">
#     <tbody>
#     <tr>
#         <th>Week</th>
#         <th>Topic</th>
#         <th>Material</th>
#         <th>Assignments</th>
#     </tr>
#     <h6>
#     <tr>
#
#         <th>1 </th>
#         <th><font size="1">
#         <ul>
#         <li>Course presentation</li>
#         <li>An brief introduction to simulation and stochastic processes.</li>
#         <li>A review of Statistics and Probability Theory</li>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#
#     </tr>
#     <tr>
#         <th>2</th>
#         <th><font size="1">
#         <ul>
#         <li> A review of Statistics and Probability Theory</li>
#         <ul>
#         <li>Theory of Probability</li>
#         <li>Normal Distribution</li>
#         </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>3</th>
#         <th><font size="1">
#         <ul>
#         <li> Probability Theory</li>
#             <ul>
#             <li>Value Expected</li>
#             <li>Bayes' Rule</li>
#             <li>Total Probability Theory</li>
#             <li>Marginal Probability</li>
#             <li>An introduction to probability distribution.</li>
#             <li>Likelihood function.</li>
#             <li>Maximum likelihood</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#
#     <tr>
#         <th>4</th>
#         <th><font size="1">
#             <ul>
#             <li>Computational Complexity Stochastic Approach</li>
#                 <ul>
#                 <li>Randomized Algorithms</li>
#                 <li>QuickSort pivot Selection</li>
#                 <li>Expected Value over algorithms</li>
#                 <li>Orden Statistics</li>
#                 </ul>
#             </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#
#     <tr>
#         <th>5</th>
#         <th><font size="1">
#         <ul>
#         <li>Bayesian Theory</li>
#             <ul>
#             <li>Bayes Rule</li>
#             <li>Bayesian Inference</li>
#             <li>Computational Bayesian Inference</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#
#     <tr>
#         <th>6</th>
#         <th><font size="1">
#         <ul>
#         <li>Bayesian Theory</li>
#             <ul>
#             <li>The gratest Theorem never told</li>
#             <li>The law of large numbers</li>
#             <li>The disorder of small numbers</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>7</th>
#         <th><font size="1">
#         <ul>
#         <li>Bayesian Theory</li>
#             <ul>
#             <li>Subjective vs objective Prior</li>
#             <li>Usefull prior to know about</li>
#             <li>Bayesian multiarmed- bandiths</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>8</th>
#         <th>
#         <font size="1">
#         <ul>
#         <li>An introduction of Stochastic Processes</li>
#             <ul>
#             <li>Definition Stochastic Processes.</li>
#             <li>Birth-Death Process</li>
#             <li>Renovation theory.</li>
#             </ul>
#         </ul>
#         </font>
#         </th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#          <th>9</th>
#         <th>
#         <font size="1">
#         <ul>
#         <li>An introduction of Stochastic Processes</li>
#             <ul>
#             <li>Bernoulli Processes.</li>
#             <li>Poisson Processes.</li>
#             <li>Birth and Death Processes.</li>
#             </ul>
#         </ul>
#         </font>
#         </th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>10</th>
#         <th><font size="1">
#         <ul>
#             <li>Stochastic Modelling</li>
#
#             <ul>
#                 <li>Markov Processes</li>
#                 <li>Markov Chain</li>
#                 <li>Transition matrix in Markov chain</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#
#     <tr>
#         <th>11</th>
#         <th><font size="1">
#         <ul>
#             <li>Stochastic Modelling</li>
#             <ul>
#             <li>Champman Kolmogorov Equation</li>
#             <li>Absorbing Markov Chain</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>12</th>
#         <th><font size="1">
#         <ul>
#             <li>Stochastic Modelling</li>
#             <ul>
#             <li>Queue Theory</li>
#             </ul>
#         </ul>
#         </font></th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>13</th>
#         <th>
#         <font size="1">
#         <ul>
#             <li>Stochastic Modelling in Information Retrieval</li>
#             <ul>
#             <li> Document Analysis</li>
#             <li> WebSearch Architecture</li>
#             <li> WebCrawling Analysis and PageRank</li>
#             </ul>
#         </ul>
#         </font>
#         </th>
#         <th></th>
#         <th></th>
#     </tr>
#     <tr>
#         <th>14</th>
#         <th><font size="1">
#             <ul>
#                 <li>Simulation and Modelling</li>
#                 <ul>
#                 <li> Introduction and development stages for simulation modelling</li>
#                 <li> Queue Simulation </li>
#                 <li>Runge Kutta Simulation</li>
#                 </ul>
#             </ul>
#             </font>
#         </th>
#         <th></th>
#         <th></th>
#     </tr>
#
#
#
#
#     </h6>
#     </tbody>
#
#
# </table>
#
# <H3>Course resources</H3>
# <h4>Books</h4>
# <ul>
# <li>Information Retrieval [<a href="https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf">Link</a>]</li>
# <li>
# Probabilistic Programming and Bayesian Methods for Hackers
# [<a href="">Link</a>]
# </li>
# <li>Gallager, Robert. Stochastic Processes Theory and Applications.</li>
# <li>Hue, Tue Huynh. Stochastic simulation and Applications in Finance with Matlab Programs.2008.Wiley. </li>
# <li>Field Richard. Stochastic Models: Theory and Simulation.2008.Sandia Laboratories.</li>
# <li> Knill, Oliver.Probability Theory and Stochastic Processes with Applications.2009.Overseas Press.</li>
# <li>Winston, Wayne. Investigación de Operaciones Aplicaciones y Algoritmos. 2004. Thomson Ed.</li>
# <li> Hillier, Liebermann. Introducción a la Investigación de Operaciones. 2010.</li>
# <li>Varela Carlos. Introducción a la Investigación de Operaciones. 1994.</li>
# </ul>
# <h4>Courses</h4>
# <ul>
# <li>MIT-Course- Discrete Stochastic Process [<a href="https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-262-discrete-stochastic-processes-spring-2011/">link</a>]</li>
# <li>Girke, Thomas. R- Programming [<a href= "http://manuals.bioinformatics.ucr.edu/home/programming-in-r">link</a>] </li>
#
# <li>Coursera, R- Programming [<a href= "https://www.coursera.org/course/rprog">link</a>]  </li>
# <li>Coursera, Machine Learning [<a href= "https://www.coursera.org/learn/machine-learning">link</a>]  </li>
#
# </ul>
